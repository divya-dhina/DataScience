# %% [markdown]
# <a href="https://colab.research.google.com/github/divya-dhina/DataScience/blob/main/Taskdsi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #Task 1
# using the "concrete strength" dataset, explore relationships betwen two continuous variables with scatter plot

# %%
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/concrete strength.csv")

# %%
x='Coarse Aggregate'
y='Fine Aggregate'
plt.scatter(df[x],df[y])
plt.title(f"Scatter plot of Coarse Aggregate vs Fine Aggregate")
plt.xlabel("Coarse Aggregate")
plt.ylabel("Fine Aggregate")
plt.show()

# %% [markdown]
# Draw a Scatter plot for the following Pandas DataFra,e with Team name and Rank points as x and y axis
# ["Australia",2500],["Bangladesh",1000],["England",2000],["India",3000],["Srilanka:,1500]

# %%
data={"Team":["Australia","Bangladesh","England","India","Srilanka"],"Points":[2500,1000,2000,3000,1500]}
df=pd.DataFrame(data)
plt.scatter(df["Team"],df['Points'])
#for i,txt in enumerate(df['Team']):
 # plt.annotate(txt,(df['Points'][i],df.index[i]))
plt.xlabel("Team Name")
plt.ylabel("Rank Point")
plt.title("Scatter plot")
plt.show()

# %% [markdown]
# #Task 2
# Write a Pandas program to count the number of rows and columns of a DataFrame.Sample Python dictionary data and list labels:
# exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew',
# 'Laura', 'Kevin', 'Jonas'],
# 'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
# 'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
# 'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
# labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
# Expected Output:
# Number of Rows: 10
# Number of Columns: 4

# %%
exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew',
'Laura', 'Kevin', 'Jonas'],
'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
df=pd.DataFrame(exam_data,index=labels)
rows=len(df)
columns=len(df.columns)
print("Number of rows: ",rows)
print("Number of columns: ",columns)
# Out:
# Number of rows:  10
# Number of columns:  4

# %% [markdown]
# #Task 3
# Write a Pandas program to select all columns, except one given column in a DataFrame. Sample Output:
# Original DataFrame
# col1 col2 col3
# 0 1 4 7
# 1 2 5 8
# 2 3 6 12
# 3 4 9 1
# 4 7 5 11
# All columns except 'col3':
# col1 col2
# 0 1 4
# 1 2 5
# 2 3 6
# 3 4 9
# 4 7 5

# %%
data={"col1":[1,2,3,4,7],"col2":[4,5,6,9,5],"col3":[7,8,12,1,11]}
df=pd.DataFrame(data)
print("Original DataFrame:")
print(df)
sel=df.loc[:,df.columns!="col3"]
print("\nAll columns except col3:")
print(sel)
# Out:
# Original DataFrame:
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6    12
# 3     4     9     1
# 4     7     5    11
#
# All columns except col3:
#    col1  col2
# 0     1     4
# 1     2     5
# 2     3     6
# 3     4     9
# 4     7     5

# %% [markdown]
# #Task 4
# Perform Bivariate analysis using the pandas DataFrame that contains information about
# two variables: (1) Hours spent studying and (2) Exam score received by 20 different
# students:

# %%
data={"Hours Studied":[6,5,4,3,7,8,9,2,4,10,11,6,7,8,9,10,3,5,8,9],"Exam Score":[60,70,76,77,80,90,78,60,40,30,45,65,75,86,45,65,75,85,55,90]}
df=pd.DataFrame(data)
corr=df["Hours Studied"].corr(df["Exam Score"])
plt.scatter(df["Hours Studied"],df["Exam Score"])
plt.title("Bivariate Analysis")
plt.xlabel("Hours Studied")
plt.ylabel("Exam Score")
plt.show()
print(f'Correlation between Hours Studied and Exam Score:',corr)
# Out:
# Correlation between Hours Studied and Exam Score: -0.19055582137799337

# %% [markdown]
# #Task 5
# Write a Pandas program to select the rows where the number of attempts in the examination is
# greater than 2. Sample Python dictionary data and list labels:
# exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew',
# 'Laura', 'Kevin', 'Jonas'],
# 'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
# 'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
# 'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
# labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
# Expected Output:
# Number of attempts in the examination is greater than 2:
# name score attempts qualify
# b Dima 9.0 3 no
# d James NaN 3 no
# f Michael 20.0 3 yes

# %%
exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew',
'Laura', 'Kevin', 'Jonas'],
'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
df=pd.DataFrame(exam_data,index=labels)
result=df[df['attempts']>2]
print("Number of attempts in the examination is greater than 2: ")
print(result)
# Out:
# Number of attempts in the examination is greater than 2:
#       name  score  attempts qualify
# b     Dima    9.0         3      no
# d    James    NaN         3      no
# f  Michael   20.0         3     yes

# %% [markdown]
# #Task 6
# Write a Pandas program to count number of columns of a DataFrame. Sample Output:
# Original DataFrame
# col1 col2 col3
# 0 1 4 7
# 1 2 5 8
# 2 3 6 12
# 3 4 9 1
# 4 7 5 11
# Number of columns:
# 3

# %%
data={"col1":[1,2,3,4,7],"col2":[4,5,6,9,5],"col3":[7,8,12,1,11]}
df=pd.DataFrame(data)
print("Original DataFrame")
print(df)
columns=len(df.columns)
print("Number of columns:\n",columns)
# Out:
# Original DataFrame
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6    12
# 3     4     9     1
# 4     7     5    11
# Number of columns:
#  3
