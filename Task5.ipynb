# %% [markdown]
# <a href="https://colab.research.google.com/github/divya-dhina/DataScience/blob/main/Task5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('/content/drive/MyDrive/Weather_Data.csv')

# %%
data.head()#display the top rows
# Out:
#        Date  Temp9am  Temp3pm  MinTemp  MaxTemp  Rainfall RainToday  \
# 0  01-02-13     20.7     20.9     19.5     22.4      15.6       Yes
# 1  02-02-13     22.4     24.8     19.5     25.6       6.0       Yes
# 2  03-02-13     23.5     23.0     21.6     24.5       6.6       Yes
# 3  04-02-13     21.4     20.9     20.2     22.8      18.8       Yes
# 4  05-02-13     22.5     25.5     19.7     25.7      77.4       Yes
#
#    Evaporation  Sunshine WindGustDir  ...  WindDir9am WindDir3pm WindSpeed9am  \
# 0          6.2       0.0           W  ...           S        SSW           17
# 1          3.4       2.7           W  ...           W          E            9
# 2          2.4       0.1           W  ...         ESE        ESE           17
# 3          2.2       0.0           W  ...         NNE          E           22
# 4          4.8       0.0           W  ...         NNE          W           11
#
#    WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  \
# ...

# %%
data.info()#provides the labels of rows and its info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3271 entries, 0 to 3270
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           3271 non-null   object
#  1   Temp9am        3271 non-null   float64
#  2   Temp3pm        3271 non-null   float64
#  3   MinTemp        3271 non-null   float64
#  4   MaxTemp        3271 non-null   float64
#  5   Rainfall       3271 non-null   float64
#  6   RainToday      3271 non-null   object
#  7   Evaporation    3271 non-null   float64
#  8   Sunshine       3271 non-null   float64
#  9   WindGustDir    3271 non-null   object
#  10  WindGustSpeed  3271 non-null   int64
#  11  WindDir9am     3271 non-null   object
#  12  WindDir3pm     3271 non-null   object
#  13  WindSpeed9am   3271 non-null   int64
#  14  WindSpeed3pm   3271 non-null   int64
#  15  Humidity9am    3271 non-null   int64
#  16  Humidity3pm    3271 non-null   int64
# ...

# %%
data.corr()
# Out:
# <ipython-input-6-c44ded798807>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                 Temp9am   Temp3pm   MinTemp   MaxTemp  Rainfall  Evaporation  \
# Temp9am        1.000000  0.828457  0.939307  0.858639 -0.054297     0.606122
# Temp3pm        0.828457  1.000000  0.753147  0.960805 -0.142748     0.474599
# MinTemp        0.939307  0.753147  1.000000  0.771005  0.013995     0.569316
# MaxTemp        0.858639  0.960805  0.771005  1.000000 -0.139306     0.510334
# Rainfall      -0.054297 -0.142748  0.013995 -0.139306  1.000000    -0.110343
# Evaporation    0.606122  0.474599  0.569316  0.510334 -0.110343     1.000000
# Sunshine       0.113891  0.345528 -0.063475  0.327422 -0.308962     0.175932
# WindGustSpeed  0.159570  0.036216  0.127792  0.073184  0.149811     0.245426
# ...

# %%
#correlation map
f,ax = plt.subplots(figsize=(10,10))
sns.heatmap(data.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
plt.show()
# Out:
# <ipython-input-8-30b58e1fffd6>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)

# %%
data.columns #display column names
# Out:
# Index(['Date', 'Temp9am', 'Temp3pm', 'MinTemp', 'MaxTemp', 'Rainfall',
#        'RainToday', 'Evaporation', 'Sunshine', 'WindGustDir', 'WindGustSpeed',
#        'WindDir9am', 'WindDir3pm', 'WindSpeed9am', 'WindSpeed3pm',
#        'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am',
#        'Cloud3pm'],
#       dtype='object')

# %%
# Line Plot
data.MinTemp.plot(kind = 'line', color = 'b',label = 'MinTemp',linewidth=1,alpha = 0.5,grid = True,linestyle = ':')
data.MaxTemp.plot(color = 'y',label = 'MaxTemp',linewidth=1, alpha = 0.5,grid = True,linestyle = '-.')
plt.legend(loc='upper right')     # legend = puts label into plot
plt.xlabel('x axis')              # label = name of label
plt.ylabel('y axis')
plt.title('Line Plot')            # title = title of plot
plt.show()

# %%
#scatter plot
data.plot(kind='scatter',x='MinTemp',y='MaxTemp',alpha=0.5,color='r')
plt.title('Scatter Plot')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
data.Rainfall.plot(kind='hist',color='b',figsize=(10,10))
plt.show()

# %% [markdown]
# PANDAS

# %%
series=data['Evaporation']
print(series)
# Out:
# 0       6.2
# 1       3.4
# 2       2.4
# 3       2.2
# 4       4.8
#        ...
# 3266    2.0
# 3267    2.0
# 3268    2.4
# 3269    1.4
# 3270    3.4
# Name: Evaporation, Length: 3271, dtype: float64

# %%
#filtering data
x=data['Sunshine']>1
data[x].head(20)
# Out:
#         Date  Temp9am  Temp3pm  MinTemp  MaxTemp  Rainfall RainToday  \
# 1   02-02-13     22.4     24.8     19.5     25.6       6.0       Yes
# 5   06-02-13     23.8     26.0     20.2     27.2       1.6       Yes
# 6   07-02-13     21.7     22.3     18.6     26.3       6.2       Yes
# 7   08-02-13     18.9     21.1     17.2     22.3      27.6       Yes
# 8   09-02-13     17.1     16.5     16.4     20.8      12.6       Yes
# 9   10-02-13     17.2     23.3     14.6     24.2       8.8        No
# 10  11-02-13     18.9     23.7     16.4     23.9       0.0        No
# 11  12-02-13     22.9     24.7     18.9     27.3       0.0       Yes
# 12  13-02-13     20.9     21.0     18.4     22.8      14.4       Yes
# 13  14-02-13     18.4     23.3     16.9     24.3       3.0        No
# 14  15-02-13     19.5     23.8     18.3     24.4       0.0        No
# 15  16-02-13     19.8     23.3     16.7     24.1       0.0        No
# 16  17-02-13     21.8     23.4     19.5     24.8       0.0        No
# ...

# %%
data[np.logical_and(data['WindSpeed3pm']>15,data['Humidity3pm']>80)]
# Out:
#           Date  Temp9am  Temp3pm  MinTemp  MaxTemp  Rainfall RainToday  \
# 0     01-02-13     20.7     20.9     19.5     22.4      15.6       Yes
# 3     04-02-13     21.4     20.9     20.2     22.8      18.8       Yes
# 75    17-04-13     17.2     16.2     13.8     20.9       1.4       Yes
# 82    24-04-13     16.2     17.2     14.7     17.9      12.6       Yes
# 122   03-06-13     15.6     16.7     15.2     19.1       4.0       Yes
# ...        ...      ...      ...      ...      ...       ...       ...
# 3158  25-09-21     21.5     20.9     19.9     23.3      27.6       Yes
# 3170  07-10-21     23.1     24.5     21.9     24.9       2.6       Yes
# 3171  08-10-21     20.3     20.5     20.0     22.7      20.0       Yes
# 3184  21-10-21     25.2     19.2     22.5     26.0       2.4       Yes
# 3252  28-12-21     13.3     14.2      8.8     15.5      54.6       Yes
#
#       Evaporation  Sunshine WindGustDir  ...  WindDir9am WindDir3pm  \
# ...

# %%
for index,Rainfall in data[['Rainfall']][0:10].iterrows():
  print(index,'->',Rainfall)
# Out:
# 0 -> Rainfall    15.6
# Name: 0, dtype: float64
# 1 -> Rainfall    6.0
# Name: 1, dtype: float64
# 2 -> Rainfall    6.6
# Name: 2, dtype: float64
# 3 -> Rainfall    18.8
# Name: 3, dtype: float64
# 4 -> Rainfall    77.4
# Name: 4, dtype: float64
# 5 -> Rainfall    1.6
# Name: 5, dtype: float64
# 6 -> Rainfall    6.2
# Name: 6, dtype: float64
# 7 -> Rainfall    27.6
# Name: 7, dtype: float64
# 8 -> Rainfall    12.6
# Name: 8, dtype: float64
# 9 -> Rainfall    8.8
# Name: 9, dtype: float64

# %%
import builtins
dir(builtins)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EncodingWarning',
#  'EnvironmentError',
#  'Exception',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
#  'PermissionError',
#  'ProcessLookupError',
# ...

# %%
n=lambda x: x**2#fast way of performing functions
print(n(2))
# Out:
# 4

# %%
y=map(lambda x:x**2,[1,2,3,4])#function for grp of data
print(list(y))
# Out:
# [1, 4, 9, 16]

# %%
z1=[1,2,3]
z2=[1,4,9]
z3=zip(z1,z2)#combines the values of two different data
print(list(z3))
# Out:
# [(1, 1), (2, 4), (3, 9)]

# %%
#List comprehension
z4=[i+5 for i in z1]
print(z4)
# Out:
# [6, 7, 8]

# %%
z5=[i-1 if (i<7) else i+1 for i in z4]
print(z5)
# Out:
# [5, 8, 9]

# %%
avg=sum(data.Rainfall)/len(data.Rainfall)
data['RainLevel']=['high ' if i>avg else 'low' for i in data.Rainfall]
data.loc[:10,["Rainfall","RainLevel"]]
# Out:
#     Rainfall RainLevel
# 0       15.6     high
# 1        6.0     high
# 2        6.6     high
# 3       18.8     high
# 4       77.4     high
# 5        1.6       low
# 6        6.2     high
# 7       27.6     high
# 8       12.6     high
# 9        8.8     high
# 10       0.0       low

# %%
data['Humidity3pm'].mean()#display mean
# Out:
# 54.69856313054112

# %%
data['Date'].count()#display the no of dates
# Out:
# 3271

# %%
data['Pressure3pm'].std()#standard deviation
# Out:
# 7.01991523113745

# %%
data['Rainfall'].min()#minimum rainfall
# Out:
# 0.0

# %%
data['Rainfall'].max()#maximum rainfall
# Out:
# 119.4

# %%
print(data['RainLevel'].value_counts())
# Out:
# low      2649
# high      622
# Name: RainLevel, dtype: int64

# %%
data.describe()
# Out:
#            Temp9am      Temp3pm      MinTemp      MaxTemp     Rainfall  \
# count  3271.000000  3271.000000  3271.000000  3271.000000  3271.000000
# mean     17.821461    21.543656    14.877102    23.005564     3.342158
# std       4.894316     4.297053     4.554710     4.483752     9.917746
# min       6.400000    10.200000     4.300000    11.700000     0.000000
# 25%      13.800000    18.400000    11.000000    19.600000     0.000000
# 50%      18.200000    21.300000    14.900000    22.800000     0.000000
# 75%      21.700000    24.500000    18.800000    26.000000     1.400000
# max      36.500000    44.700000    27.600000    45.800000   119.400000
#
#        Evaporation     Sunshine  WindGustSpeed  WindSpeed9am  WindSpeed3pm  \
# count  3271.000000  3271.000000    3271.000000   3271.000000   3271.000000
# mean      5.175787     7.168970      41.476307     15.077041     19.294405
# std       2.757684     3.815966      10.806951      7.043825      7.453331
# ...

# %%
#Melting data
melted=pd.melt(frame=data.head(),id_vars='Date',value_vars=['Rainfall','Evaporation'])
melted
# Out:
#        Date     variable  value
# 0  01-02-13     Rainfall   15.6
# 1  02-02-13     Rainfall    6.0
# 2  03-02-13     Rainfall    6.6
# 3  04-02-13     Rainfall   18.8
# 4  05-02-13     Rainfall   77.4
# 5  01-02-13  Evaporation    6.2
# 6  02-02-13  Evaporation    3.4
# 7  03-02-13  Evaporation    2.4
# 8  04-02-13  Evaporation    2.2
# 9  05-02-13  Evaporation    4.8

# %%
#concatenation
cc=pd.concat([data['Humidity9am'],data['Humidity3pm']],axis=1)
cc.head(10)
# Out:
#    Humidity9am  Humidity3pm
# 0           92           84
# 1           83           73
# 2           88           86
# 3           83           90
# 4           88           74
# 5           69           62
# 6           75           80
# 7           77           61
# 8           92           91
# 9           80           53

# %%
data.dtypes
# Out:
# Date              object
# Temp9am          float64
# Temp3pm          float64
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# RainToday         object
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed      int64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am       int64
# WindSpeed3pm       int64
# Humidity9am        int64
# Humidity3pm        int64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am           int64
# Cloud3pm           int64
# RainLevel         object
# dtype: object

# %%
data['WindGustDir']=data['WindGustDir'].astype('category')#converts the datatype from str to category
data.dtypes
# Out:
# Date               object
# Temp9am           float64
# Temp3pm           float64
# MinTemp           float64
# MaxTemp           float64
# Rainfall          float64
# RainToday          object
# Evaporation       float64
# Sunshine          float64
# WindGustDir      category
# WindGustSpeed       int64
# WindDir9am         object
# WindDir3pm         object
# WindSpeed9am        int64
# WindSpeed3pm        int64
# Humidity9am         int64
# Humidity3pm         int64
# Pressure9am       float64
# Pressure3pm       float64
# Cloud9am            int64
# Cloud3pm            int64
# RainLevel          object
# dtype: object

# %%
data['WindGustDir'].value_counts(dropna=False)
# Out:
# W      1425
# SSE     239
# ENE     214
# NE      169
# S       169
# SSW     163
# NNE     149
# ESE     140
# WSW     134
# E       122
# WNW      79
# NW       68
# SE       68
# NNW      52
# SW       50
# N        30
# Name: WindGustDir, dtype: int64

# %%
data1=data.loc[0:10,['Humidity9am','Humidity3pm']]
data1.plot()
# Out:
# <Axes: >

# %%
data1.plot(subplots=True)
plt.show()

# %%
data1.plot(kind='hist',y='Humidity3pm',bins=50,range=(0,100),cumulative=True)
# Out:
# <Axes: ylabel='Frequency'>

# %%
data.index.name='index_name'
data.head()
# Out:
#                 Date  Temp9am  Temp3pm  MinTemp  MaxTemp  Rainfall RainToday  \
# index_name
# 0           01-02-13     20.7     20.9     19.5     22.4      15.6       Yes
# 1           02-02-13     22.4     24.8     19.5     25.6       6.0       Yes
# 2           03-02-13     23.5     23.0     21.6     24.5       6.6       Yes
# 3           04-02-13     21.4     20.9     20.2     22.8      18.8       Yes
# 4           05-02-13     22.5     25.5     19.7     25.7      77.4       Yes
#
#             Evaporation  Sunshine WindGustDir  ...  WindDir3pm WindSpeed9am  \
# index_name                                     ...
# 0                   6.2       0.0           W  ...         SSW           17
# 1                   3.4       2.7           W  ...           E            9
# 2                   2.4       0.1           W  ...         ESE           17
# 3                   2.2       0.0           W  ...           E           22
# ...

# %%
data3=data
data3.index=range(100,3371)#changing the index range
data3.head()
# Out:
#          Date  Temp9am  Temp3pm  MinTemp  MaxTemp  Rainfall RainToday  \
# 100  01-02-13     20.7     20.9     19.5     22.4      15.6       Yes
# 101  02-02-13     22.4     24.8     19.5     25.6       6.0       Yes
# 102  03-02-13     23.5     23.0     21.6     24.5       6.6       Yes
# 103  04-02-13     21.4     20.9     20.2     22.8      18.8       Yes
# 104  05-02-13     22.5     25.5     19.7     25.7      77.4       Yes
#
#      Evaporation  Sunshine WindGustDir  ...  WindDir3pm WindSpeed9am  \
# 100          6.2       0.0           W  ...         SSW           17
# 101          3.4       2.7           W  ...           E            9
# 102          2.4       0.1           W  ...         ESE           17
# 103          2.2       0.0           W  ...           E           22
# 104          4.8       0.0           W  ...           W           11
#
#     WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  \
# ...

# %%
data3=data3.set_index('Temp9am')
data3
# Out:
#          Temp3pm  MinTemp  MaxTemp  Rainfall RainToday  Evaporation  Sunshine  \
# Temp9am
# 20.7        20.9     19.5     22.4      15.6       Yes          6.2       0.0
# 22.4        24.8     19.5     25.6       6.0       Yes          3.4       2.7
# 23.5        23.0     21.6     24.5       6.6       Yes          2.4       0.1
# 21.4        20.9     20.2     22.8      18.8       Yes          2.2       0.0
# 22.5        25.5     19.7     25.7      77.4       Yes          4.8       0.0
# ...          ...      ...      ...       ...       ...          ...       ...
# 10.5        17.9      8.6     19.6       0.0        No          2.0       7.8
# 11.0        18.7      9.3     19.2       0.0        No          2.0       9.2
# 10.2        17.3      9.4     17.7       0.0        No          2.4       2.7
# 12.4        19.0     10.1     19.3       0.0        No          1.4       9.3
# 9.4         18.8      7.6     19.3       0.0        No          3.4       9.4
#
# ...

# %%
#setting index as Rainfall and EVaporation
data1=data.set_index(['Evaporation'])
data1.head(20)
# Out:
#                  Date  Temp9am  Temp3pm  MinTemp  MaxTemp  Rainfall RainToday  \
# Evaporation
# 6.2          01-02-13     20.7     20.9     19.5     22.4      15.6       Yes
# 3.4          02-02-13     22.4     24.8     19.5     25.6       6.0       Yes
# 2.4          03-02-13     23.5     23.0     21.6     24.5       6.6       Yes
# 2.2          04-02-13     21.4     20.9     20.2     22.8      18.8       Yes
# 4.8          05-02-13     22.5     25.5     19.7     25.7      77.4       Yes
# 2.6          06-02-13     23.8     26.0     20.2     27.2       1.6       Yes
# 5.2          07-02-13     21.7     22.3     18.6     26.3       6.2       Yes
# 5.8          08-02-13     18.9     21.1     17.2     22.3      27.6       Yes
# 4.8          09-02-13     17.1     16.5     16.4     20.8      12.6       Yes
# 4.4          10-02-13     17.2     23.3     14.6     24.2       8.8        No
# 6.4          11-02-13     18.9     23.7     16.4     23.9       0.0        No
# ...

# %%
data1.pivot(index='Date',columns='RainToday',values='Rainfall')
# Out:
# RainToday    No   Yes
# Date
# 01-01-14    0.0   NaN
# 01-01-15    0.4   NaN
# 01-01-16    0.2   NaN
# 01-01-17    0.0   NaN
# 01-01-18   20.0   NaN
# ...         ...   ...
# 31-12-17    NaN  30.6
# 31-12-18    0.0   NaN
# 31-12-19    0.0   NaN
# 31-12-20    NaN  93.8
# 31-12-21    NaN  38.8
#
# [3271 rows x 2 columns]

# %%
data.groupby('RainToday')[['Rainfall','Sunshine']].mean()
# Out:
#            Rainfall  Sunshine
# RainToday
# No         1.603633  8.364203
# Yes        8.301767  3.759246
